# %%
from signal_generator import SignalGenerator
s = SignalGenerator()
list_trade = s.Strategy_HK_onOpen()
# Out:
# /Users/tp_mini/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# Ticker
# 9888.HK    0.029005
# 9961.HK    0.023745
# 9988.HK    0.021594
# 1810.HK    0.021477
# 2386.HK    0.015873
# Name: 2025-01-27 00:00:00+00:00, dtype: float64
# Strategy List for HK onOpen:
# Ticker
# 1810.HK    37.1
# 2386.HK     6.5
# Name: 2025-01-27 00:00:00+00:00, dtype: float64

# %%
list_trade_prev = s.Strategy_HK_prevClose()
# Out:
# Ticker
# 1024.HK    0.035049
# 0011.HK    0.025761
# 1171.HK    0.025410
# 0027.HK    0.024693
# 2386.HK    0.023347
# Name: 2025-01-27 00:00:00+00:00, dtype: float64
# Strategy List for HK prevClose:
# Ticker
# 1024.HK    42.10
# 0011.HK    98.30
# 1171.HK     8.37
# 0027.HK    32.80
# 2386.HK     6.50
# Name: 2025-01-27 00:00:00+00:00, dtype: float64
